# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/dog_and_cat/
# Out:
# /content/drive/My Drive/Project/dog_and_cat

# %%
# !python extract_feature.py --dataset ../datasets/kaggle_dog_and_cat/train --output ../datasets/kaggle_dog_and_cat/hdf5/resnet_feature.hdf5
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Loading model ResNet
# WARNING: Logging before flag parsing goes to stderr.
# W0831 15:07:46.552711 139964542113664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 15:07:46.564130 139964542113664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0831 15:07:46.568807 139964542113664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# ...

# %%
# !python train_model_extracted_feature.py --database ../datasets/kaggle_dog_and_cat/hdf5/resnet_feature.hdf5 --model ../model/dog_and_cat_resnet.model
# Out:
# [INFO] Turning parameters for LogisticRegression
# tcmalloc: large alloc 15052800000 bytes == 0x2e2e000 @  0x7f9e92c8e1e7 0x7f9e8fef7ca1 0x7f9e8ff5c778 0x7f9e8fefb4a1 0x53edb5 0x57ec0c 0x4f88ba 0x4fa6c0 0x4f6128 0x56fd6b 0x7f9e7a905961 0x5a105c 0x57c2fe 0x545708 0x4f9ba9 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7f9e9288bb97 0x5bdf6a
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt
#
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
# ...

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/
# Out:
# /content/drive/My Drive/Project

# %%
# !python minigooglenet_cifar10.py --output output --model model/minigooglenet_cifar10.hdf5
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# ...
# 170500096/170498071 [==============================] - 11s 0us/step
# tcmalloc: large alloc 1228800000 bytes == 0x12c6e000 @  0x7feeefaae1e7 0x7feeebf1cca1 0x7feeebf81778 0x7feeebf840a5 0x7feeec014a82 0x4f8925 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7feeef6abb97 0x5bdf6a
# WARNING: Logging before flag parsing goes to stderr.
# W0831 18:29:51.605952 140664204306304 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 18:29:51.606469 140664204306304 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/
# Out:
# /content/drive/My Drive/Project

# %%
# !python minigooglenet_cifar10.py --output output --model model/minigooglenet_cifar10.hdf5
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# tcmalloc: large alloc 1228800000 bytes == 0x12e66000 @  0x7fa48d7b31e7 0x7fa489c21ca1 0x7fa489c86778 0x7fa489c890a5 0x7fa489d19a82 0x4f8925 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7fa48d3b0b97 0x5bdf6a
# WARNING: Logging before flag parsing goes to stderr.
# W0901 04:53:49.215723 140344729433984 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0901 04:53:49.216101 140344729433984 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...
