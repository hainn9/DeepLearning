# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/dog_and_cat/
# Out:
# /content/drive/My Drive/Project/dog_and_cat

# %%
# !python build_dog_and-cat.py
# Out:
# Using TensorFlow backend.
# [INFO] Loading and Preprocessing data
# Traceback (most recent call last):
#   File "build_dog_and-cat.py", line 21, in <module>
#     split = train_test_split(trainDatas, trainLabels, test_size=config.NUM_TEST_IMAGES, random_state=42, stratify=trainLabels)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py", line 2100, in train_test_split
#     default_test_size=0.25)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py", line 1734, in _validate_shuffle_split
#     '(0, 1) range'.format(test_size, n_samples))
# ValueError: test_size=2500 should be either positive and smaller than the number of samples 0 or a float in the (0, 1) range

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in /usr/local/lib/python3.6/dist-packages (0.21.3)
# ...

# %%
# !python build_dog_and-cat.py
# Out:
# Using TensorFlow backend.
# [INFO] Loading and Preprocessing data
# lenght of trainDatas 25000
# [INFO] Building ../datasets/kaggle_dog_and_cat/hdf5/train.hdf5
# Building datasets: 100% |#######################################| Time:  0:09:07
# [INFO] Building ../datasets/kaggle_dog_and_cat/hdf5/test.hdf5
# Building datasets: 100% |#######################################| Time:  0:01:18
# [INFO] Building ../datasets/kaggle_dog_and_cat/hdf5/val.hdf5
# Building datasets: 100% |#######################################| Time:  0:01:41
# [INFO] Serializing mean

# %%
cd ..
# Out:
# /content/drive/My Drive/Project

# %%
cd datasets/kaggle_dog_and_cat/hdf5/
# Out:
# /content/drive/My Drive/Project/datasets/kaggle_dog_and_cat/hdf5

# %%
ll
# Out:
# total 38400203
# -rw------- 1 root  3932182048 Aug 31 09:00 test.hdf5
# -rw------- 1 root 31457442048 Aug 31 08:59 train.hdf5
# -rw------- 1 root  3932182048 Aug 31 09:02 val.hdf5

# %%
ls
# Out:
# test.hdf5  train.hdf5  val.hdf5

# %%
cd ..
# Out:
# /content/drive/My Drive/Project/datasets/kaggle_dog_and_cat

# %%
cd ../..
# Out:
# /content/drive/My Drive/Project

# %%
cd dog_and_cat/
# Out:
# /content/drive/My Drive/Project/dog_and_cat

# %%
ls
# Out:
# build_dog_and-cat.py  dl_cv/                   train_alexnet.py
# config/               dog_and_cat_train.ipynb

# %%
# !python train_alexnet.py
# Out:
# Using TensorFlow backend.
# [INFO] Preparing data
# [INFO] Building model
# WARNING: Logging before flag parsing goes to stderr.
# W0831 12:00:16.346754 139922422495104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 12:00:16.347941 139922422495104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0831 12:00:16.349324 139922422495104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/dog_and_cat/
# Out:
# /content/drive/My Drive/Project/dog_and_cat

# %%
# !python extract_feature.py
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Loading model ResNet50
# WARNING: Logging before flag parsing goes to stderr.
# W0831 14:35:26.738015 139862713214848 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 14:35:26.748557 139862713214848 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0831 14:35:26.753064 139862713214848 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# ...

# %%
# !python extract_feature.py
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Loading model ResNet50
# WARNING: Logging before flag parsing goes to stderr.
# W0831 14:38:17.038750 140211744454528 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 14:38:17.049309 140211744454528 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0831 14:38:17.053735 140211744454528 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# ...

# %%
# !python extract_feature.py
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Loading model ResNet50
# WARNING: Logging before flag parsing goes to stderr.
# W0831 14:39:26.528168 140203379730304 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 14:39:26.538715 140203379730304 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0831 14:39:26.542852 140203379730304 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# ...

# %%
# !python extract_feature.py
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Loading model ResNet50
# WARNING: Logging before flag parsing goes to stderr.
# W0831 14:42:04.840251 140400957560704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 14:42:04.851328 140400957560704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0831 14:42:04.855360 140400957560704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# ...

# %%
# !python extract_feature.py --dataset ../datasets/kaggle_dog_and_cat/train --output ../datasets/kaggle_dog_and_cat/hdf5/resnet_feature.hdf5
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Loading model ResNet
# WARNING: Logging before flag parsing goes to stderr.
# W0831 14:49:35.264470 140459538438016 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 14:49:35.275594 140459538438016 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0831 14:49:35.279850 140459538438016 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# ...
