# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/advance_technique/
# Out:
# /content/drive/My Drive/Project/advance_technique

# %%
# !python minivggnet_flower.py --dataset ../datasets/flowers
# Out:
# Using TensorFlow backend.
# [INFO] Preprocessing data
# [INFO] Processed 500/1360
# [INFO] Processed 1000/1360
# [INFO] Building model
# WARNING: Logging before flag parsing goes to stderr.
# W0818 17:39:59.416540 140608943843200 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0818 17:39:59.417863 140608943843200 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0818 17:39:59.419179 140608943843200 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
# !python minivggnet_flower_augmentation.py --dataset ../datasets/flowers
# Out:
# Using TensorFlow backend.
# [INFO] Preprocessing data
# [INFO] Processed 500/1360
# [INFO] Processed 1000/1360
# [INFO] Building model
# WARNING: Logging before flag parsing goes to stderr.
# W0818 17:54:33.865907 140242782799744 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0818 17:54:33.867085 140242782799744 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0818 17:54:33.868182 140242782799744 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/advance_technique/
# Out:
# /content/drive/My Drive/Project/advance_technique

# %%
# !python minivggnet_flower_augmentation.py --dataset ../datasets/flowers
# Out:
# Using TensorFlow backend.
# [INFO] Preprocessing data
# [INFO] Processed 500/1360
# [INFO] Processed 1000/1360
# [INFO] Building model
# WARNING: Logging before flag parsing goes to stderr.
# W0819 12:53:55.048190 140038638581632 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0819 12:53:55.049324 140038638581632 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0819 12:53:55.050325 140038638581632 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
ls
# Out:
# advance_technique.ipynb             minivggnet_flower.png
# dl_cv/                              minivggnet_flower.py
# minivggnet_flower_augmentation.png  vgg16_extract_feature.py
# minivggnet_flower_augmentation.py

# %%
# !python vgg16_extract_feature.py --dataset ../datasets/animals --output vgg16_animals_features.hdf5
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Loading model VGG16
# WARNING: Logging before flag parsing goes to stderr.
# W0819 15:55:11.345831 140349631383424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0819 15:55:11.357069 140349631383424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0819 15:55:11.359053 140349631383424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
import h5py

# %%
db = h5py.File("vgg16_animals_features.hdf5")

# %%
db.keys()
# Out:
# KeysView(<HDF5 file "vgg16_animals_features.hdf5" (mode r+)>)

# %%
list(db.keys())
# Out:
# ['features', 'label_names', 'labels']

# %%
db["features"].shape
# Out:
# (3000, 25088)

# %%
db["labels"].shape
# Out:
# (3000,)

# %%
# !python vgg16_extract_feature.py --dataset ../datasets/flowers --output vgg16_flowers_features.hdf5
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Loading model VGG16
# WARNING: Logging before flag parsing goes to stderr.
# W0819 16:16:25.317597 139806527772544 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0819 16:16:25.329952 139806527772544 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0819 16:16:25.332098 139806527772544 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
db = h5py.File("vgg16_flowers_features.hdf5")

# %%
list(db.keys())
# Out:
# ['features', 'label_names', 'labels']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/advance_technique/
# Out:
# /content/drive/My Drive/Project/advance_technique

# %%
ls
# Out:
# advance_technique.ipynb             minivggnet_flower.py
# dl_cv/                              train_model_on_extracted_feature.py
# minivggnet_flower_augmentation.png  vgg16_animals_features.hdf5
# minivggnet_flower_augmentation.py   vgg16_extract_feature.py
# minivggnet_flower.png               vgg16_flowers_features.hdf5

# %%
# !python train_model_on_extracted_feature.py --database vgg16_animals_features.hdf5 --model vgg16_logistic_regression_animals_model.cpickle
# Out:
# [INFO] Turning parameters for LogisticRegression
# /usr/local/lib/python3.6/dist-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [INFO] Best parameter is {'C': 0.1}
# [INFO] Evaluating model
#               precision    recall  f1-score   support
#
#         cats       0.97      0.99      0.98       238
#         dogs       0.99      0.97      0.98       251
#        panda       1.00      1.00      1.00       261
#
#     accuracy                           0.99       750
#    macro avg       0.99      0.99      0.99       750
# weighted avg       0.99      0.99      0.99       750
#
# [INFO] Saving model

# %%
# !python train_model_on_extracted_feature.py --database vgg16_flowers_features.hdf5 --model vgg16_logistic_regression_flowers_model.cpickle
# Out:
# [INFO] Turning parameters for LogisticRegression
# /usr/local/lib/python3.6/dist-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [INFO] Best parameter is {'C': 1000.0}
# [INFO] Evaluating model
#               precision    recall  f1-score   support
#
#     Bluebell       0.95      0.90      0.93        21
#    Buttercup       1.00      0.86      0.92        21
#   Colts'Foot       0.89      0.86      0.88        29
#      Cowslip       0.50      0.82      0.62        11
#       Crocus       0.74      1.00      0.85        14
#     Daffodil       0.91      0.81      0.86        26
#        Daisy       1.00      1.00      1.00        18
#    Dandelion       0.91      0.95      0.93        22
#   Fritillary       1.00      0.87      0.93        23
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/advance_technique/
# Out:
# /content/drive/My Drive/Project/advance_technique

# %%
ls
# Out:
# advance_technique.ipynb
# dl_cv/
# minivggnet_flower_augmentation.png
# minivggnet_flower_augmentation.py
# minivggnet_flower.png
# minivggnet_flower.py
# ranked_accuracy.py
# train_model_on_extracted_feature.py
# vgg16_animals_features.hdf5
# vgg16_extract_feature.py
# vgg16_flowers_features.hdf5
# vgg16_logistic_regression_animals_model.cpickle
# vgg16_logistic_regression_flowers_model.cpickle

# %%
# !python ranked_accuracy.py --database vgg16_flowers_features.hdf5 --model vgg16_logistic_regression_flowers_model.cpickle
# Out:
# [INFO] Load pre-trained model
# [INFO] Calculate accuracy
# [INFO] Rank-1 accuracy: 0.29%
# [INFO] Rank-5 accuracy: 0.29%

# %%
ls
# Out:
# advance_technique.ipynb
# dl_cv/
# minivggnet_flower_augmentation.png
# minivggnet_flower_augmentation.py
# minivggnet_flower.png
# minivggnet_flower.py
# ranked_accuracy.py
# train_model_on_extracted_feature.py
# vgg16_animals_features.hdf5
# vgg16_extract_feature.py
# vgg16_flowers_features.hdf5
# vgg16_logistic_regression_animals_model.cpickle
# vgg16_logistic_regression_flowers_model.cpickle

# %%
# !python finetune_train_model.py --dataset ../datasets/flowers --model finetune_flowers_model.model
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Processed 500/1360
# [INFO] Processed 1000/1360
# [INFO] Loading dataset finish
# [INFO] Preprocessing data
# tcmalloc: large alloc 1637744640 bytes == 0x6984a000 @  0x7fb151cb01e7 0x7fb1473adca1 0x7fb147415580 0x7fb1474a5a82 0x4f8925 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7fb1518adb97 0x5bdf6a
# tcmalloc: large alloc 1228308480 bytes == 0xa4f6000 @  0x7fb151cb01e7 0x7fb1473adca1 0x7fb147412778 0x7fb147412893 0x7fb1474625a4 0x7fb1474a1ea0 0x4f8925 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x59c3a9 0x575290 0x56f034 0x56f29e 0x53ee21 0x57ec0c 0x4f88ba 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0
# [INFO] Buiding base model
# WARNING: Logging before flag parsing goes to stderr.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/advance_technique/
# Out:
# /content/drive/My Drive/Project/advance_technique

# %%
# !python finetune_train_model.py --dataset ../datasets/flowers --model finetune_flowers_model.model
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Processed 500/1360
# [INFO] Processed 1000/1360
# [INFO] Loading dataset finish
# [INFO] Preprocessing data
# tcmalloc: large alloc 1637744640 bytes == 0x68036000 @  0x7f295c2e01e7 0x7f29519ddca1 0x7f2951a45580 0x7f2951ad5a82 0x4f8925 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7f295beddb97 0x5bdf6a
# tcmalloc: large alloc 1228308480 bytes == 0xc9a16000 @  0x7f295c2e01e7 0x7f29519ddca1 0x7f2951a42778 0x7f2951a42893 0x7f2951a925a4 0x7f2951ad1ea0 0x4f8925 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x59c3a9 0x575290 0x56f034 0x56f29e 0x53ee21 0x57ec0c 0x4f88ba 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0
# [INFO] Buiding base model
# WARNING: Logging before flag parsing goes to stderr.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/advance_technique/
# Out:
# /content/drive/My Drive/Project/advance_technique

# %%
# !python finetune_train_model.py --dataset ../datasets/flowers --model finetune_flowers_model.model
# Out:
# Using TensorFlow backend.
# [INFO] Loading dataset
# [INFO] Processed 500/1360
# [INFO] Processed 1000/1360
# [INFO] Loading dataset finish
# [INFO] Preprocessing data
# tcmalloc: large alloc 1637744640 bytes == 0x68bd0000 @  0x7f1fc61101e7 0x7f1fbb80dca1 0x7f1fbb875580 0x7f1fbb905a82 0x4f8925 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7f1fc5d0db97 0x5bdf6a
# tcmalloc: large alloc 1228308480 bytes == 0x98f8000 @  0x7f1fc61101e7 0x7f1fbb80dca1 0x7f1fbb872778 0x7f1fbb872893 0x7f1fbb8c25a4 0x7f1fbb901ea0 0x4f8925 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x59c3a9 0x575290 0x56f034 0x56f29e 0x53ee21 0x57ec0c 0x4f88ba 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0
# [INFO] Buiding base model
# WARNING: Logging before flag parsing goes to stderr.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/advance_technique/
# Out:
# /content/drive/My Drive/Project/advance_technique

# %%
# !python ensemble_train_model.py --model ../model --output ../output
# Out:
# Using TensorFlow backend.
# tcmalloc: large alloc 1228800000 bytes == 0x1381e000 @  0x7fecd52a01e7 0x7fecd170eca1 0x7fecd1773778 0x7fecd17760a5 0x7fecd1806a82 0x4f8925 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7fecd4e9db97 0x5bdf6a
# [INFO] Training model 1/5
# WARNING: Logging before flag parsing goes to stderr.
# W0829 15:56:24.622064 140655169718144 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0829 15:56:24.622942 140655169718144 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...
