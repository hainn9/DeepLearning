# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
dc drive/My\ Drive
# Out:
#   File "<ipython-input-2-1b98098feb46>", line 1
#     dc drive/My\ Drive
#            ^
# SyntaxError: invalid syntax

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/emotion_recognition/
# Out:
# /content/drive/My Drive/Project/emotion_recognition

# %%
cd ../datasets/
# Out:
# /content/drive/My Drive/Project/datasets

# %%
# !tar -zxvf fer2013.tar
# Out:
# fer2013/fer2013.csv
# fer2013/README
# fer2013/fer2013.bib
# fer2013/

# %%
ls
# Out:
# animals/  fer2013/  fer2013.tar  flowers/  kaggle_dog_and_cat/  SMILEsmileD/

# %%
cd fer2013/
# Out:
# /content/drive/My Drive/Project/datasets/fer2013

# %%
cd ../../emotion_recognition/
# Out:
# /content/drive/My Drive/Project/emotion_recognition

# %%
cd ../datasets/
# Out:
# /content/drive/My Drive/Project/datasets

# %%
cp -a fer2013\ \(1\) fer2013/

# %%
cp -a fer2013_a fer2013\ \(1\)

# %%
cd ..
# Out:
# /content/drive/My Drive/Project

# %%
cd emotion_recognition/
# Out:
# /content/drive/My Drive/Project/emotion_recognition

# %%
ls
# Out:
# build_dataset.py  emotion_detector.py        train_model.py
# config/           emotion_recognition.ipynb
# dl_cv/            test_model.py

# %%
# !python build_dataset.py
# Out:
# Using TensorFlow backend.
# [INFO] Loading data
# Traceback (most recent call last):
#   File "build_dataset.py", line 6, in <module>
#     f = open(config.INPUT_PATH)
# FileNotFoundError: [Errno 2] No such file or directory: '../datasets/fer2013/fer2013/fer2013.csv'

# %%
cd ../datasets/
# Out:
# /content/drive/My Drive/Project/datasets

# %%
ls
# Out:
#  animals/  'fer2013 (1)'/   flowers/   kaggle_dog_and_cat/   SMILEsmileD/

# %%
mv fer2013\ \(1\) fer2013

# %%
cd fer2013/
# Out:
# /content/drive/My Drive/Project/datasets/fer2013

# %%
ls
# Out:
# fer2013/  hdf5/

# %%
cd ../../emotion_recognition/
# Out:
# /content/drive/My Drive/Project/emotion_recognition

# %%
# !python build_dataset.py
# Out:
# Using TensorFlow backend.
# [INFO] Loading data
# [INFO] Building ../datasets/fer2013/hdf5/train.hdf5
# [INFO] Building ../datasets/fer2013/hdf5/val.hdf5
# [INFO] Building ../datasets/fer2013/hdf5/test.hdf5

# %%
ll ../datasets/fer2013/hdf5/
# Out:
# total 646254
# -rw------- 1 root  66183208 Sep  2 14:55 test.hdf5
# -rw------- 1 root 529396008 Sep  2 14:55 train.hdf5
# -rw------- 1 root  66183208 Sep  2 14:55 val.hdf5

# %%
ls
# Out:
# build_dataset.py  emotion_detector.py        train_model.py
# config/           emotion_recognition.ipynb
# dl_cv/            test_model.py

# %%
# !python train_model.py --checkpoint ../checkpoint/
# Out:
# Using TensorFlow backend.
# [INFO] Compiling model
# WARNING: Logging before flag parsing goes to stderr.
# W0902 16:21:00.603281 140456901191552 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0902 16:21:00.614497 140456901191552 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0902 16:21:00.616256 140456901191552 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/emotion_recognition/
# Out:
# /content/drive/My Drive/Project/emotion_recognition

# %%
# !python train_model.py --checkpoint ../checkpoint/
# Out:
# Using TensorFlow backend.
# [INFO] Compiling model
# WARNING: Logging before flag parsing goes to stderr.
# W0903 15:21:06.687043 140420279154560 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0903 15:21:06.697909 140420279154560 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0903 15:21:06.699357 140420279154560 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# ...

# %%
# !python train_model.py --checkpoint ../checkpoint --model ../checkpoint/epoch_40.hdf5 --startEpoch 40 --lr 1e-4
# Out:
# Using TensorFlow backend.
# [INFO] Loading model ../checkpoint/epoch_40.hdf5
# WARNING: Logging before flag parsing goes to stderr.
# W0903 15:03:51.273863 140328678999936 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0903 15:03:51.285438 140328678999936 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0903 15:03:51.311062 140328678999936 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd Project/emotion_recognition/
# Out:
# /content/drive/My Drive/Project/emotion_recognition
